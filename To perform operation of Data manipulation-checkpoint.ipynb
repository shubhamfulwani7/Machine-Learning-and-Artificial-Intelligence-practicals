# %%
#Aim:To perform operation of Data manipulation on Data set.

# %%
#Name: Shubham M. Fulwani
#Roll no. : 15
#Sec: C
#Subject:ET-II

# %%
#importing the basic library
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\shubh\\Desktop'

# %%
os.chdir('C:\\Users\\shubh\\Desktop')

# %%
data=pd.read_csv("diabetes.csv")

# %%
data.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# 0   121.0  medium  118.0   59.0    NaN    NaN   29.0  38.0     720.0
# 1   218.0   large  112.0   68.0    NaN    NaN   46.0  48.0     360.0
# 2   256.0   large  190.0   92.0  185.0   92.0   49.0  57.0     180.0
# 3   119.0   large  110.0   50.0    NaN    NaN   33.0  38.0     480.0
# 4   183.0  medium  138.0   80.0    NaN    NaN   44.0  41.0     300.0

# %%
data.head(10)
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
# 5  1008  248.0        94  69.0    3.6   4.81  Buckingham   34    male    71.0
# 6  1011  195.0        92  41.0    4.8   4.84  Buckingham   30    male    69.0
# 7  1015  227.0        75  44.0    5.2   3.94  Buckingham   37    male    59.0
# 8  1016  177.0        87  49.0    3.6   4.84  Buckingham   45    male    69.0
# 9  1022  263.0        89  40.0    6.6   5.78  Buckingham   55  female    63.0
#
#    weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# ...

# %%
data.tail()
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb location  age  gender  \
# 398  41506  296.0       369  46.0    6.4  16.110001   Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000   Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000   Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000   Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN   Louisa   68  female
#
#      height  weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# 398    69.0   173.0  medium  138.0   94.0  130.0   94.0   35.0  39.0     210.0
# 399    63.0   154.0  medium  140.0  100.0  146.0  102.0   32.0  43.0     180.0
# 400    69.0   167.0   small  120.0   70.0    NaN    NaN   33.0  40.0      20.0
# 401    63.0   197.0  medium  120.0   78.0    NaN    NaN   41.0  48.0     255.0
# 402    64.0   220.0  medium  100.0   72.0    NaN    NaN   49.0  58.0     900.0

# %%
#Pandas .size, .shape and .ndim are used to return size, shape and dimensions of data

# %%
#Returns tuple of shape (Rows, columns) of data
data.shape
# Out:
# (403, 19)

# %%
#Returns size of dataframe/series which is equivalent to total number of elements. 
#That is rows x columns.
data.size
# Out:
# 7657

# %%
#Returns dimension of dataframe/series. 1 for one dimension (series), 2 for two dimension
data.ndim
# Out:
# 2

# %%
data.columns
# Out:
# Index(['id', 'chol', 'stab.glu', 'hdl', 'ratio', 'glyhb', 'location', 'age',
#        'gender', 'height', 'weight', 'frame', 'bp.1s', 'bp.1d', 'bp.2s',
#        'bp.2d', 'waist', 'hip', 'time.ppn'],
#       dtype='object')

# %%
data.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# 0   121.0  medium  118.0   59.0    NaN    NaN   29.0  38.0     720.0
# 1   218.0   large  112.0   68.0    NaN    NaN   46.0  48.0     360.0
# 2   256.0   large  190.0   92.0  185.0   92.0   49.0  57.0     180.0
# 3   119.0   large  110.0   50.0    NaN    NaN   33.0  38.0     480.0
# 4   183.0  medium  138.0   80.0    NaN    NaN   44.0  41.0     300.0

# %%
# Drop is use to Drop one or more than one column from a Data 
# axis=1 i.e Column
data.drop(labels="age",axis=1)
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb    location  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham    male
# ..     ...    ...       ...   ...    ...        ...         ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa  female
# 402  41756  159.0        88  79.0    2.0        NaN      Louisa  female
#
#      height  weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# ...

# %%
data.drop(labels=["age","stab.glu"],axis=1)
# Out:
#         id   chol   hdl  ratio      glyhb    location  gender  height  weight  \
# 0     1000  203.0  56.0    3.6   4.310000  Buckingham  female    62.0   121.0
# 1     1001  165.0  24.0    6.9   4.440000  Buckingham  female    64.0   218.0
# 2     1002  228.0  37.0    6.2   4.640000  Buckingham  female    61.0   256.0
# 3     1003   78.0  12.0    6.5   4.630000  Buckingham    male    67.0   119.0
# 4     1005  249.0  28.0    8.9   7.720000  Buckingham    male    68.0   183.0
# ..     ...    ...   ...    ...        ...         ...     ...     ...     ...
# 398  41506  296.0  46.0    6.4  16.110001      Louisa    male    69.0   173.0
# 399  41507  284.0  54.0    5.3   4.390000      Louisa  female    63.0   154.0
# 400  41510  194.0  38.0    5.1  13.630000      Louisa  female    69.0   167.0
# 401  41752  199.0  52.0    3.8   4.490000      Louisa  female    63.0   197.0
# 402  41756  159.0  79.0    2.0        NaN      Louisa  female    64.0   220.0
#
# ...

# %%
data.drop(labels=2,axis=0)
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# 5     1008  248.0        94  69.0    3.6   4.810000  Buckingham   34    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN      Louisa   68  female
#
# ...

# %%
data.head(10)
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
# 5  1008  248.0        94  69.0    3.6   4.81  Buckingham   34    male    71.0
# 6  1011  195.0        92  41.0    4.8   4.84  Buckingham   30    male    69.0
# 7  1015  227.0        75  44.0    5.2   3.94  Buckingham   37    male    59.0
# 8  1016  177.0        87  49.0    3.6   4.84  Buckingham   45    male    69.0
# 9  1022  263.0        89  40.0    6.6   5.78  Buckingham   55  female    63.0
#
#    weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# ...

# %%
# Drop is use to Drop one or more than one column from a Data 
# axis=0 i.e Row
data.drop(labels=[2,3],axis=0)
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# 5     1008  248.0        94  69.0    3.6   4.810000  Buckingham   34    male
# 6     1011  195.0        92  41.0    4.8   4.840000  Buckingham   30    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN      Louisa   68  female
#
# ...
